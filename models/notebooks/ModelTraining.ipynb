# %% [markdown]
# # 📊 MLP Model Training - Hierarchical Demand Forecasting
#
# ## 🔍 Въведение
# Този notebook е посветен на обучението на Multi-Layer Perceptron (MLP) модел за прогнозиране на продажби. Моделът използва обработените данни от DataProcessing.ipynb и следва архитектурата, специално разработена за таблични данни с lag features, rolling statistics и календарни характеристики.
#
# ---
#
# ## 🎯 Цел
# Изграждане и обучение на MLP модел за regression задача (прогнозиране на продажби 1 ден напред), който:
# ✅ Използва обработените данни от DataProcessing pipeline
# ✅ Следва оптимална архитектура за таблични данни
# ✅ Включва Batch Normalization и Dropout за стабилност и regularization
# ✅ Имплементира early stopping за предотвратяване на overfitting
# ✅ Използва подходящи метрики за regression (MSE, MAE, RMSE)
#
# ---
#
# ## 📋 План на notebook-а
#
# | Секция | Описание |
# |--------|----------|
# | **0. Setup** | Импортиране на библиотеки, настройка на пътища |
# | **1. Load Processed Data** | Зареждане на X_train_scaled, y_train и т.н. |
# | **2. Model Architecture** | Дефиниране на MLP архитектурата |
# | **3. Compile Model** | Конфигуриране на optimizer, loss и metrics |
# | **4. Training** | Обучение с validation и early stopping |
# | **5. Evaluation** | Оценка на модела върху test set |
# | **6. Save Model** | Запазване на обучения модел |
#
# ---

# %% [markdown]
# ## 0. Setup

# %%
import torch
import os
os.environ["KERAS_BACKEND"] = "torch"

from pathlib import Path
import numpy as np
import pandas as pd
import pickle
import json

from sklearn.metrics import mean_squared_error, mean_absolute_error
import keras
from keras import layers, callbacks

# Проектови пътища
# Определяне на root директорията (работи независимо от текущата директория)
if Path.cwd().name == "models":
    PROJ_ROOT = Path.cwd().resolve().parent
else:
    PROJ_ROOT = Path.cwd().resolve()

DATA_PROCESSED = PROJ_ROOT / "data" 
MODELS_DIR = PROJ_ROOT / "models"
DATA_DIR = PROJ_ROOT / "data"
MODELS_DIR.mkdir(parents=True, exist_ok=True)
# Поддиректории в models/
TRAINED_MODELS_DIR = MODELS_DIR / "trained_models"
TRAINING_DIR = MODELS_DIR / "training"

# Създаване на директории (ако не съществуват)
for dir_path in [TRAINED_MODELS_DIR, TRAINING_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)


DATA_PROCESSED.mkdir(parents=True, exist_ok=True)

# Проверка за GPU
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

# Seed за възпроизводимост
GLOBAL_SEED = 42
np.random.seed(GLOBAL_SEED)
torch.manual_seed(GLOBAL_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(GLOBAL_SEED)

print(f"\n✅ Setup завършен")
print(f"Keras backend: {keras.config.backend()}")
# Out:
# CUDA available: False
#
# ✅ Setup завършен
# Keras backend: torch

# %% [markdown]
# ## 1. Load Processed Data
#
# Зареждаме обработените данни от DataProcessing pipeline.
#
# **Как да заредите данните:**
#
# 1. **Препоръчителен метод:** Изпълнете DataProcessing.ipynb (секции 0-9) - той автоматично запазва данните в `data/processed/processed_data.pkl`
# 2. Клетката по-долу автоматично зарежда данните от файла (по-бързо и надеждно)
# 3. **Алтернативен метод:** Ако файлът не съществува, опитва се да използва `%run` magic
#
# След зареждане ще имате в паметта:
# - `X_train_scaled`, `y_train`
# - `X_val_scaled`, `y_val`
# - `X_test_scaled`, `y_test`

# %%
processed_data_path = DATA_PROCESSED / "/Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/data/processed_data.pkl"

if processed_data_path.exists():
    print(f"📂 Зареждане на данни от файл: {processed_data_path}")
    with open(processed_data_path, "rb") as f:
        data = pickle.load(f)
    
    X_train_scaled = data["X_train_scaled"]
    y_train = data["y_train"]
    X_val_scaled = data["X_val_scaled"]
    y_val = data["y_val"]
    X_test_scaled = data["X_test_scaled"]
    y_test = data["y_test"]
    
    print("✅ Данните са заредени от файл!")
else:
    print(f"⚠️  Файлът {processed_data_path} не съществува")
    print("\n💡 Решение:")
    print("   1. Изпълнете DataProcessing.ipynb (секции 0-9) за да създадете файла")
    print("   2. Или използвайте %run magic по-долу (ако е наличен)")
    
    # Алтернативен метод: %run magic
    try:
        from IPython import get_ipython
        ipython = get_ipython()
        if ipython is not None:
            print("\n🔄 Опит за зареждане чрез %run magic...")
            ipython.run_line_magic('run', '../data/DataProcessing.ipynb')
            print("✅ Данните са заредени чрез %run magic")
        else:
            raise NameError("Not running in IPython environment")
    except (NameError, ModuleNotFoundError, AttributeError) as e:
        print(f"\n❌ %run magic не е наличен: {e}")
        raise ValueError("Няма налични данни! Изпълнете DataProcessing.ipynb първо.")
# Out:
# 📂 Зареждане на данни от файл: /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/data/processed_data.pkl
# ✅ Данните са заредени от файл!

# %%
# Проверка на заредените данни
print("📊 Проверка на данните...\n")

try:
    # Проверяваме дали данните са в паметта
    X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test
    
    print("✅ Данните са успешно заредени!\n")
    
    # Размери на данните
    print(f"📊 Данни за обучение:")
    print(f"   X_train_scaled: {X_train_scaled.shape}")
    print(f"   y_train: {y_train.shape}")
    print(f"\n📊 Данни за валидация:")
    print(f"   X_val_scaled: {X_val_scaled.shape}")
    print(f"   y_val: {y_val.shape}")
    print(f"\n📊 Данни за тестване:")
    print(f"   X_test_scaled: {X_test_scaled.shape}")
    print(f"   y_test: {y_test.shape}")
    
except NameError as e:
    print(f"❌ Данните не са заредени: {e}")
    print("\n💡 Решение:")
    print("   1. Изпълнете DataProcessing.ipynb (секции 0-9) за да създадете processed_data.pkl")
    print("   2. Или използвайте %run magic в клетката по-горе")
    raise
# Out:
# 📊 Проверка на данните...
#
# ✅ Данните са успешно заредени!
#
# 📊 Данни за обучение:
#    X_train_scaled: (755405, 36)
#    y_train: (755405,)
#
# 📊 Данни за валидация:
#    X_val_scaled: (161590, 36)
#    y_val: (161590,)
#
# 📊 Данни за тестване:
#    X_test_scaled: (162155, 36)
#    y_test: (162155,)

# %%
# Подготовка на данните за обучение

# Брой на features
n_features = X_train_scaled.shape[1]
print(f"✅ Брой features: {n_features}")

# Конвертиране към numpy arrays (ако са pandas DataFrames)
if isinstance(X_train_scaled, pd.DataFrame):
    X_train_scaled = X_train_scaled.values
    X_val_scaled = X_val_scaled.values
    X_test_scaled = X_test_scaled.values

if isinstance(y_train, pd.Series):
    y_train = y_train.values
    y_val = y_val.values
    y_test = y_test.values

# Конвертиране към float32 за по-добра производителност
X_train_scaled = X_train_scaled.astype("float32")
X_val_scaled = X_val_scaled.astype("float32")
X_test_scaled = X_test_scaled.astype("float32")
y_train = y_train.astype("float32")
y_val = y_val.astype("float32")
y_test = y_test.astype("float32")

print(f"\n✅ Данните са готови за обучение (float32)")
print(f"   Train: {len(X_train_scaled):,} редове")
print(f"   Val:   {len(X_val_scaled):,} редове")
print(f"   Test:  {len(X_test_scaled):,} редове")
# Out:
# ✅ Брой features: 36
#
# ✅ Данните са готови за обучение (float32)
#    Train: 755,405 редове
#    Val:   161,590 редове
#    Test:  162,155 редове

# %% [markdown]
# ## **2. Model Architecture**
#
# ### **➤ 1. Input Layer**
# - Размерът = броя на входните признаци (features)
# - В нашия случай: **input_dim=36** (36 features)
#
# ### **➤ 2. Hidden Layers**
# Архитектура: **512 → 256 → 128 → 64 → 1** (класическа пирамида)
# - Dense(512, ReLU) + BatchNorm + Dropout(0.25)
# - Dense(256, ReLU) + BatchNorm + Dropout(0.2)
# - Dense(128, ReLU) + BatchNorm + Dropout(0.1)
# - Dense(64, ReLU)
#
# ### **➤ 3. Output Layer**
# - 1 неврон (прогноза за продажби)
# - Активация: **linear** (regression задача)
#
# ---

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu", input_shape=(n_features,), name="dense_1"),
    layers.BatchNormalization(),
    layers.Dropout(0.25),

    layers.Dense(256, activation="relu", name="dense_2"),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    layers.Dense(128, activation="relu", name="dense_3"),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    layers.Dense(64, activation="relu", name="dense_4"),
    layers.Dense(1, activation="linear", name="output")
], name="MLP_wider")

# Показване на архитектурата
print("📊 Model Architecture:")
model.summary()

# Показване на броя параметри
total_params = model.count_params()

try:
    # За PyTorch backend, използваме numel() за всеки weight
    trainable_params = sum(w.numel() if hasattr(w, 'numel') else int(np.prod(w.shape)) for w in model.trainable_weights)
except:
    # Fallback: в повечето случаи всички параметри са trainable
    trainable_params = total_params

print(f"\n📈 Параметри:")
print(f"   Общо: {total_params:,}")
print(f"   Trainable: {trainable_params:,}")
# Out:
# /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 📊 Model Architecture:
# Model: "MLP_wider"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 512)            │        18,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 195,073 (762.00 KB)
#  Trainable params: 193,281 (755.00 KB)
#  Non-trainable params: 1,792 (7.00 KB)
# 📈 Параметри:
#    Общо: 195,073
#    Trainable: 193,281

# %% [markdown]
# ## 3. Compile Model
#
# **Optimizer:** Adam (adaptive learning rate)
#
# **Loss:** Mean Squared Error (MSE) - стандартна за regression
#
# **Metrics:** MSE, MAE, RMSE

# %%
def root_mean_squared_error(y_true, y_pred):
    return keras.ops.sqrt(keras.ops.mean(keras.ops.square(y_pred - y_true)))

# Компилиране на модела
model.compile(
    optimizer="adam",
    loss="mse", 
    metrics=[
        "mse", 
        "mae", 
        root_mean_squared_error,  
    ],
)

print("✅ Моделът е компилиран")
print(f"   Optimizer: Adam")
print(f"   Loss: MSE (Mean Squared Error)")
print(f"   Metrics: MSE, MAE, RMSE")
# Out:
# ✅ Моделът е компилиран
#    Optimizer: Adam
#    Loss: MSE (Mean Squared Error)
#    Metrics: MSE, MAE, RMSE

# %% [markdown]
# ## 4. Training
#
# Обучение с:
# - **Early Stopping** - спира при липса на подобрение върху validation set
# - **Model Checkpoint** - запазва най-добрия модел
# - **ReduceLROnPlateau** - намалява learning rate при плато
# - **Validation split** - използваме отделен validation set

# %%
callbacks_list = [
    callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,  
        restore_best_weights=True,  # Връща най-добрите тежести
        verbose=1,
    ),
    
    # Model checkpoint - запазва най-добрия модел
    callbacks.ModelCheckpoint(
        filepath=str(TRAINED_MODELS_DIR / "best_mlp_model.keras"),
        monitor="val_loss",
        save_best_only=True,
        verbose=1,
    ),
    
    # Reduce learning rate при липса на подобрение
    callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,  # Намалява learning rate с 50%
        patience=5,  # Изчаква 5 epochs
        min_lr=1e-7,
        verbose=1,
    ),
]

# Параметри за обучение
BATCH_SIZE = 1024
EPOCHS = 100

print(f"🚀 Започване на обучение...")
print(f"   Batch size: {BATCH_SIZE}")
print(f"   Max epochs: {EPOCHS}")
print(f"   Early stopping: patience=10")
print(f"   Model checkpoint: {MODELS_DIR / 'best_mlp_model.keras'}")

# Обучение на модела
history = model.fit(
    X_train_scaled,
    y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val_scaled, y_val),
    callbacks=callbacks_list,
    verbose=1,
)

print("\n✅ Обучението завърши!")
# Out:
# 🚀 Започване на обучение...
#    Batch size: 1024
#    Max epochs: 100
#    Early stopping: patience=10
#    Model checkpoint: /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/best_mlp_model.keras
# Epoch 1/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.6998 - mae: 1.0051 - mse: 6.6998 - root_mean_squared_error: 3.1545
# Epoch 1: val_loss improved from None to 6.80567, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - loss: 5.8360 - mae: 0.9102 - mse: 5.8360 - root_mean_squared_error: 3.1887 - val_loss: 6.8057 - val_mae: 0.9711 - val_mse: 6.8057 - val_root_mean_squared_error: 2.0311 - learning_rate: 0.0010
# Epoch 2/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.3322 - mae: 0.8437 - mse: 5.3322 - root_mean_squared_error: 3.1980
# Epoch 2: val_loss improved from 6.80567 to 5.82356, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.4998 - mae: 0.8468 - mse: 5.4998 - root_mean_squared_error: 3.2241 - val_loss: 5.8236 - val_mae: 0.9368 - val_mse: 5.8236 - val_root_mean_squared_error: 2.0330 - learning_rate: 0.0010
# Epoch 3/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.3141 - mae: 0.8169 - mse: 5.3141 - root_mean_squared_error: 3.2077
# Epoch 3: val_loss improved from 5.82356 to 5.02605, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 5.4155 - mae: 0.8195 - mse: 5.4155 - root_mean_squared_error: 3.2324 - val_loss: 5.0261 - val_mae: 0.9153 - val_mse: 5.0261 - val_root_mean_squared_error: 2.0362 - learning_rate: 0.0010
# Epoch 4/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.2289 - mae: 0.8193 - mse: 5.2289 - root_mean_squared_error: 3.2041
# Epoch 4: val_loss improved from 5.02605 to 4.99918, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - loss: 5.3734 - mae: 0.8154 - mse: 5.3734 - root_mean_squared_error: 3.2404 - val_loss: 4.9992 - val_mae: 1.0610 - val_mse: 4.9992 - val_root_mean_squared_error: 2.1541 - learning_rate: 0.0010
# Epoch 5/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.5899 - mae: 0.8122 - mse: 5.5899 - root_mean_squared_error: 3.2636
# Epoch 5: val_loss did not improve from 4.99918
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 5.3875 - mae: 0.8094 - mse: 5.3875 - root_mean_squared_error: 3.2368 - val_loss: 33.1010 - val_mae: 5.1477 - val_mse: 33.1010 - val_root_mean_squared_error: 5.6371 - learning_rate: 0.0010
# Epoch 6/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.3217 - mae: 0.8016 - mse: 5.3217 - root_mean_squared_error: 3.2312
# Epoch 6: val_loss did not improve from 4.99918
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.3485 - mae: 0.8016 - mse: 5.3485 - root_mean_squared_error: 3.2447 - val_loss: 5.0368 - val_mae: 1.1233 - val_mse: 5.0368 - val_root_mean_squared_error: 2.1797 - learning_rate: 0.0010
# Epoch 7/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2949 - mae: 0.7914 - mse: 5.2949 - root_mean_squared_error: 3.2398
# Epoch 7: val_loss did not improve from 4.99918
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 5.3448 - mae: 0.7943 - mse: 5.3448 - root_mean_squared_error: 3.2456 - val_loss: 5.3515 - val_mae: 0.8518 - val_mse: 5.3515 - val_root_mean_squared_error: 2.0474 - learning_rate: 0.0010
# Epoch 8/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.6140 - mae: 0.7975 - mse: 5.6140 - root_mean_squared_error: 3.2944
# Epoch 8: val_loss improved from 4.99918 to 4.83350, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 5.3091 - mae: 0.7891 - mse: 5.3091 - root_mean_squared_error: 3.2493 - val_loss: 4.8335 - val_mae: 0.9812 - val_mse: 4.8335 - val_root_mean_squared_error: 2.1370 - learning_rate: 0.0010
# Epoch 9/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.2451 - mae: 0.7800 - mse: 5.2451 - root_mean_squared_error: 3.2420
# Epoch 9: val_loss did not improve from 4.83350
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - loss: 5.2787 - mae: 0.7817 - mse: 5.2787 - root_mean_squared_error: 3.2553 - val_loss: 6.5407 - val_mae: 1.7268 - val_mse: 6.5407 - val_root_mean_squared_error: 2.6103 - learning_rate: 0.0010
# Epoch 10/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2376 - mae: 0.7852 - mse: 5.2376 - root_mean_squared_error: 3.2266
# Epoch 10: val_loss did not improve from 4.83350
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - loss: 5.2944 - mae: 0.7845 - mse: 5.2944 - root_mean_squared_error: 3.2557 - val_loss: 4.8439 - val_mae: 0.9437 - val_mse: 4.8439 - val_root_mean_squared_error: 2.0587 - learning_rate: 0.0010
# Epoch 11/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1339 - mae: 0.7763 - mse: 5.1339 - root_mean_squared_error: 3.2122
# Epoch 11: val_loss did not improve from 4.83350
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 23s 31ms/step - loss: 5.3043 - mae: 0.7812 - mse: 5.3043 - root_mean_squared_error: 3.2472 - val_loss: 5.1730 - val_mae: 0.9736 - val_mse: 5.1730 - val_root_mean_squared_error: 2.0224 - learning_rate: 0.0010
# Epoch 12/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.1096 - mae: 0.7743 - mse: 5.1096 - root_mean_squared_error: 3.2277
# Epoch 12: val_loss did not improve from 4.83350
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 5.2625 - mae: 0.7750 - mse: 5.2625 - root_mean_squared_error: 3.2615 - val_loss: 4.9452 - val_mae: 1.0453 - val_mse: 4.9452 - val_root_mean_squared_error: 2.1117 - learning_rate: 0.0010
# Epoch 13/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.1135 - mae: 0.7665 - mse: 5.1135 - root_mean_squared_error: 3.2140
# Epoch 13: val_loss did not improve from 4.83350
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.2522 - mae: 0.7698 - mse: 5.2522 - root_mean_squared_error: 3.2576 - val_loss: 4.8554 - val_mae: 0.8349 - val_mse: 4.8554 - val_root_mean_squared_error: 2.0763 - learning_rate: 0.0010
# Epoch 14/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.0093 - mae: 0.7636 - mse: 5.0093 - root_mean_squared_error: 3.2266
# Epoch 14: val_loss did not improve from 4.83350
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.2346 - mae: 0.7663 - mse: 5.2346 - root_mean_squared_error: 3.2635 - val_loss: 4.9641 - val_mae: 0.8170 - val_mse: 4.9641 - val_root_mean_squared_error: 2.0831 - learning_rate: 5.0000e-04
# Epoch 15/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.1123 - mae: 0.7577 - mse: 5.1123 - root_mean_squared_error: 3.2558
# Epoch 15: val_loss did not improve from 4.83350
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 5.2107 - mae: 0.7601 - mse: 5.2107 - root_mean_squared_error: 3.2662 - val_loss: 5.1325 - val_mae: 1.1849 - val_mse: 5.1325 - val_root_mean_squared_error: 2.1714 - learning_rate: 5.0000e-04
# Epoch 16/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.0564 - mae: 0.7579 - mse: 5.0564 - root_mean_squared_error: 3.2327
# Epoch 16: val_loss did not improve from 4.83350
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 5.2253 - mae: 0.7605 - mse: 5.2253 - root_mean_squared_error: 3.2624 - val_loss: 4.8478 - val_mae: 0.8450 - val_mse: 4.8478 - val_root_mean_squared_error: 2.0603 - learning_rate: 5.0000e-04
# Epoch 17/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.0815 - mae: 0.7579 - mse: 5.0815 - root_mean_squared_error: 3.2537
# Epoch 17: val_loss improved from 4.83350 to 4.78357, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 5.2027 - mae: 0.7587 - mse: 5.2027 - root_mean_squared_error: 3.2656 - val_loss: 4.7836 - val_mae: 0.8740 - val_mse: 4.7836 - val_root_mean_squared_error: 2.0666 - learning_rate: 5.0000e-04
# Epoch 18/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.2835 - mae: 0.7600 - mse: 5.2835 - root_mean_squared_error: 3.2863
# Epoch 18: val_loss did not improve from 4.78357
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.2024 - mae: 0.7587 - mse: 5.2024 - root_mean_squared_error: 3.2651 - val_loss: 4.8469 - val_mae: 0.9954 - val_mse: 4.8469 - val_root_mean_squared_error: 2.1390 - learning_rate: 5.0000e-04
# Epoch 19/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.0705 - mae: 0.7584 - mse: 5.0705 - root_mean_squared_error: 3.2370
# Epoch 19: val_loss did not improve from 4.78357
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.2015 - mae: 0.7584 - mse: 5.2015 - root_mean_squared_error: 3.2661 - val_loss: 4.8015 - val_mae: 0.8966 - val_mse: 4.8015 - val_root_mean_squared_error: 2.1018 - learning_rate: 5.0000e-04
# Epoch 20/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.2651 - mae: 0.7563 - mse: 5.2651 - root_mean_squared_error: 3.2716
# Epoch 20: val_loss improved from 4.78357 to 4.75958, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.2023 - mae: 0.7558 - mse: 5.2023 - root_mean_squared_error: 3.2632 - val_loss: 4.7596 - val_mae: 0.8856 - val_mse: 4.7596 - val_root_mean_squared_error: 2.0888 - learning_rate: 5.0000e-04
# Epoch 21/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2015 - mae: 0.7609 - mse: 5.2015 - root_mean_squared_error: 3.2783
# Epoch 21: val_loss did not improve from 4.75958
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 23s 31ms/step - loss: 5.2036 - mae: 0.7579 - mse: 5.2036 - root_mean_squared_error: 3.2679 - val_loss: 5.5841 - val_mae: 1.4411 - val_mse: 5.5841 - val_root_mean_squared_error: 2.3923 - learning_rate: 5.0000e-04
# Epoch 22/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2925 - mae: 0.7589 - mse: 5.2925 - root_mean_squared_error: 3.2911
# Epoch 22: val_loss did not improve from 4.75958
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - loss: 5.1855 - mae: 0.7554 - mse: 5.1855 - root_mean_squared_error: 3.2690 - val_loss: 5.3323 - val_mae: 1.3176 - val_mse: 5.3323 - val_root_mean_squared_error: 2.3125 - learning_rate: 5.0000e-04
# Epoch 23/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.1340 - mae: 0.7587 - mse: 5.1340 - root_mean_squared_error: 3.2507
# Epoch 23: val_loss did not improve from 4.75958
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.1943 - mae: 0.7569 - mse: 5.1943 - root_mean_squared_error: 3.2636 - val_loss: 4.8651 - val_mae: 0.8300 - val_mse: 4.8651 - val_root_mean_squared_error: 2.0746 - learning_rate: 5.0000e-04
# Epoch 24/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.0407 - mae: 0.7544 - mse: 5.0407 - root_mean_squared_error: 3.2603
# Epoch 24: val_loss improved from 4.75958 to 4.73851, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/trained_models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.1831 - mae: 0.7535 - mse: 5.1831 - root_mean_squared_error: 3.2662 - val_loss: 4.7385 - val_mae: 0.8550 - val_mse: 4.7385 - val_root_mean_squared_error: 2.1128 - learning_rate: 5.0000e-04
# Epoch 25/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.0644 - mae: 0.7534 - mse: 5.0644 - root_mean_squared_error: 3.2449
# Epoch 25: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 5.1854 - mae: 0.7558 - mse: 5.1854 - root_mean_squared_error: 3.2659 - val_loss: 4.7623 - val_mae: 0.9436 - val_mse: 4.7623 - val_root_mean_squared_error: 2.0873 - learning_rate: 5.0000e-04
# Epoch 26/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1277 - mae: 0.7527 - mse: 5.1277 - root_mean_squared_error: 3.2548
# Epoch 26: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - loss: 5.1799 - mae: 0.7545 - mse: 5.1799 - root_mean_squared_error: 3.2701 - val_loss: 4.9533 - val_mae: 1.0668 - val_mse: 4.9533 - val_root_mean_squared_error: 2.0954 - learning_rate: 5.0000e-04
# Epoch 27/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.0867 - mae: 0.7534 - mse: 5.0867 - root_mean_squared_error: 3.2394
# Epoch 27: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - loss: 5.1816 - mae: 0.7530 - mse: 5.1816 - root_mean_squared_error: 3.2674 - val_loss: 4.7625 - val_mae: 0.8492 - val_mse: 4.7625 - val_root_mean_squared_error: 2.0929 - learning_rate: 5.0000e-04
# Epoch 28/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.1333 - mae: 0.7570 - mse: 5.1333 - root_mean_squared_error: 3.2850
# Epoch 28: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - loss: 5.1867 - mae: 0.7523 - mse: 5.1867 - root_mean_squared_error: 3.2685 - val_loss: 4.7783 - val_mae: 0.9899 - val_mse: 4.7783 - val_root_mean_squared_error: 2.1231 - learning_rate: 5.0000e-04
# Epoch 29/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.1607 - mae: 0.7487 - mse: 5.1607 - root_mean_squared_error: 3.2400
# Epoch 29: val_loss did not improve from 4.73851
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 24s 32ms/step - loss: 5.1740 - mae: 0.7507 - mse: 5.1740 - root_mean_squared_error: 3.2702 - val_loss: 4.8438 - val_mae: 0.8375 - val_mse: 4.8438 - val_root_mean_squared_error: 2.0896 - learning_rate: 5.0000e-04
# Epoch 30/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.0920 - mae: 0.7508 - mse: 5.0920 - root_mean_squared_error: 3.2808
# Epoch 30: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 5.1610 - mae: 0.7470 - mse: 5.1610 - root_mean_squared_error: 3.2683 - val_loss: 4.7562 - val_mae: 0.8379 - val_mse: 4.7562 - val_root_mean_squared_error: 2.0939 - learning_rate: 2.5000e-04
# Epoch 31/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.4837 - mae: 0.7484 - mse: 5.4837 - root_mean_squared_error: 3.3095
# Epoch 31: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 5.1581 - mae: 0.7465 - mse: 5.1581 - root_mean_squared_error: 3.2704 - val_loss: 4.8025 - val_mae: 0.8285 - val_mse: 4.8025 - val_root_mean_squared_error: 2.0828 - learning_rate: 2.5000e-04
# Epoch 32/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2722 - mae: 0.7459 - mse: 5.2722 - root_mean_squared_error: 3.2935
# Epoch 32: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 5.1507 - mae: 0.7453 - mse: 5.1507 - root_mean_squared_error: 3.2721 - val_loss: 4.8291 - val_mae: 0.8720 - val_mse: 4.8291 - val_root_mean_squared_error: 2.0569 - learning_rate: 2.5000e-04
# Epoch 33/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2011 - mae: 0.7472 - mse: 5.2011 - root_mean_squared_error: 3.2804
# Epoch 33: val_loss did not improve from 4.73851
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 5.1541 - mae: 0.7451 - mse: 5.1541 - root_mean_squared_error: 3.2668 - val_loss: 4.7728 - val_mae: 0.8352 - val_mse: 4.7728 - val_root_mean_squared_error: 2.0936 - learning_rate: 2.5000e-04
# Epoch 34/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.1397 - mae: 0.7444 - mse: 5.1397 - root_mean_squared_error: 3.2893
# Epoch 34: val_loss did not improve from 4.73851
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 5.1458 - mae: 0.7440 - mse: 5.1458 - root_mean_squared_error: 3.2745 - val_loss: 4.7842 - val_mae: 0.8469 - val_mse: 4.7842 - val_root_mean_squared_error: 2.0809 - learning_rate: 2.5000e-04
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
#
# ✅ Обучението завърши!

# %% [markdown]
# ## 5. Evaluation
#
# Оценка на модела върху test set с подходящи метрики за regression.

# %%
# Прогнози върху test set
print("📊 Оценка върху test set...")
y_pred = model.predict(X_test_scaled, batch_size=BATCH_SIZE, verbose=1)
y_pred = y_pred.flatten()  # Преобразуване към 1D array

# Изчисляване на метрики
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

# Допълнителни метрики

print(f"\n📈 Метрики върху test set:")
print(f"   MSE:  {mse:.4f}")
print(f"   MAE:  {mae:.4f}")
print(f"   RMSE: {rmse:.4f}")

# Сравнение на train и validation loss от history
if history:
    final_train_loss = history.history["loss"][-1]
    final_val_loss = history.history["val_loss"][-1]
    
    print(f"\n📊 Final loss:")
    print(f"   Train: {final_train_loss:.4f}")
    print(f"   Val:   {final_val_loss:.4f}")
    print(f"   Test:  {mse:.4f}")
    
    # Проверка за overfitting
    if final_val_loss > final_train_loss * 1.2:
        print(f"\n⚠️  Възможно overfitting (val_loss > train_loss * 1.2)")
    else:
        print(f"\n✅ Няма признаци за overfitting")
# Out:
# 📊 Оценка върху test set...
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# 📈 Метрики върху test set:
#    MSE:  5.0392
#    MAE:  0.8943
#    RMSE: 2.2448
#
# 📊 Final loss:
#    Train: 5.1458
#    Val:   4.7842
#    Test:  5.0392
#
# ✅ Няма признаци за overfitting

# %% [markdown]
# ### 5.1. Training History Visualization
#
# Визуализация на learning curves за анализ на обучението.

# %%
import matplotlib.pyplot as plt

if history:
    # Създаване на фигура с две подграфи
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss curves
    axes[0].plot(history.history["loss"], label="Train Loss", linewidth=2)
    axes[0].plot(history.history["val_loss"], label="Validation Loss", linewidth=2)
    axes[0].set_title("Model Loss", fontsize=14, fontweight="bold")
    axes[0].set_xlabel("Epoch", fontsize=12)
    axes[0].set_ylabel("Loss (MSE)", fontsize=12)
    axes[0].legend(fontsize=11)
    axes[0].grid(True, alpha=0.3)
    
    # MAE curves
    if "mae" in history.history:
        axes[1].plot(history.history["mae"], label="Train MAE", linewidth=2)
        axes[1].plot(history.history["val_mae"], label="Validation MAE", linewidth=2)
        axes[1].set_title("Model MAE", fontsize=14, fontweight="bold")
        axes[1].set_xlabel("Epoch", fontsize=12)
        axes[1].set_ylabel("MAE", fontsize=12)
        axes[1].legend(fontsize=11)
        axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Запазване на фигурата
    fig.savefig(TRAINING_DIR / "training_history.png", dpi=300, bbox_inches="tight")
    print(f"✅ Training history визуализация запазена: {MODELS_DIR / 'training_history.png'}")
# Out:
# ✅ Training history визуализация запазена: /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/notebooks/models/training_history.png

# %% [markdown]
# ## Confusion Matrix

# %%
import matplotlib.pyplot as plt

residuals = y_test - y_pred
plt.scatter(y_pred, residuals, alpha=0.3)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted')
plt.show()

plt.scatter(y_test, y_pred, alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Predicted vs Actual')
plt.show()
