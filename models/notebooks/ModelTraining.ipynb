# %% [markdown]
# # 📊 MLP Model Training - Hierarchical Demand Forecasting
#
# ## 🔍 Въведение
# Този notebook е посветен на обучението на Multi-Layer Perceptron (MLP) модел за прогнозиране на продажби. Моделът използва обработените данни от DataProcessing.ipynb и следва архитектурата, специално разработена за таблични данни с lag features, rolling statistics и календарни характеристики.
#
# ---
#
# ## 🎯 Цел
# Изграждане и обучение на MLP модел за regression задача (прогнозиране на продажби 1 ден напред), който:
# ✅ Използва обработените данни от DataProcessing pipeline
# ✅ Следва оптимална архитектура за таблични данни
# ✅ Включва Batch Normalization и Dropout за стабилност и regularization
# ✅ Имплементира early stopping за предотвратяване на overfitting
# ✅ Използва подходящи метрики за regression (MSE, MAE, RMSE)
#
# ---
#
# ## 📋 План на notebook-а
#
# | Секция | Описание |
# |--------|----------|
# | **0. Setup** | Импортиране на библиотеки, настройка на пътища |
# | **1. Load Processed Data** | Зареждане на X_train_scaled, y_train и т.н. |
# | **2. Model Architecture** | Дефиниране на MLP архитектурата |
# | **3. Compile Model** | Конфигуриране на optimizer, loss и metrics |
# | **4. Training** | Обучение с validation и early stopping |
# | **5. Evaluation** | Оценка на модела върху test set |
# | **6. Save Model** | Запазване на обучения модел |
#
# ---

# %% [markdown]
# ## 0. Setup

# %%
import torch
import os
os.environ["KERAS_BACKEND"] = "torch"

from pathlib import Path
import numpy as np
import pandas as pd
import pickle
import json

from sklearn.metrics import mean_squared_error, mean_absolute_error
import keras
from keras import layers, callbacks

# Проектови пътища
# Определяне на root директорията (работи независимо от текущата директория)
if Path.cwd().name == "models":
    PROJ_ROOT = Path.cwd().resolve().parent
else:
    PROJ_ROOT = Path.cwd().resolve()

DATA_PROCESSED = PROJ_ROOT / "data" 
MODELS_DIR = PROJ_ROOT / "models"
DATA_DIR = PROJ_ROOT / "data"
MODELS_DIR.mkdir(parents=True, exist_ok=True)
# Поддиректории в models/
TRAINED_MODELS_DIR = MODELS_DIR / "trained_models"
TRAINING_DIR = MODELS_DIR / "training"

# Създаване на директории (ако не съществуват)
for dir_path in [TRAINED_MODELS_DIR, TRAINING_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)


DATA_PROCESSED.mkdir(parents=True, exist_ok=True)

# Проверка за GPU
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

# Seed за възпроизводимост
GLOBAL_SEED = 42
np.random.seed(GLOBAL_SEED)
torch.manual_seed(GLOBAL_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(GLOBAL_SEED)

print(f"\n✅ Setup завършен")
print(f"Keras backend: {keras.config.backend()}")
# Out:
# CUDA available: False
#
# ✅ Setup завършен
# Keras backend: torch

# %% [markdown]
# ## 1. Load Processed Data
#
# Зареждаме обработените данни от DataProcessing pipeline.
#
# **Как да заредите данните:**
#
# 1. **Препоръчителен метод:** Изпълнете DataProcessing.ipynb (секции 0-9) - той автоматично запазва данните в `data/processed/processed_data.pkl`
# 2. Клетката по-долу автоматично зарежда данните от файла (по-бързо и надеждно)
# 3. **Алтернативен метод:** Ако файлът не съществува, опитва се да използва `%run` magic
#
# След зареждане ще имате в паметта:
# - `X_train_scaled`, `y_train`
# - `X_val_scaled`, `y_val`
# - `X_test_scaled`, `y_test`

# %%
processed_data_path = DATA_PROCESSED / "processed_data.pkl"

if processed_data_path.exists():
    print(f"📂 Зареждане на данни от файл: {processed_data_path}")
    with open(processed_data_path, "rb") as f:
        data = pickle.load(f)
    
    X_train_scaled = data["X_train_scaled"]
    y_train = data["y_train"]
    X_val_scaled = data["X_val_scaled"]
    y_val = data["y_val"]
    X_test_scaled = data["X_test_scaled"]
    y_test = data["y_test"]
    
    print("✅ Данните са заредени от файл!")
else:
    print(f"⚠️  Файлът {processed_data_path} не съществува")
    print("\n💡 Решение:")
    print("   1. Изпълнете DataProcessing.ipynb (секции 0-9) за да създадете файла")
    print("   2. Или използвайте %run magic по-долу (ако е наличен)")
    
    # Алтернативен метод: %run magic
    try:
        from IPython import get_ipython
        ipython = get_ipython()
        if ipython is not None:
            print("\n🔄 Опит за зареждане чрез %run magic...")
            ipython.run_line_magic('run', '../data/DataProcessing.ipynb')
            print("✅ Данните са заредени чрез %run magic")
        else:
            raise NameError("Not running in IPython environment")
    except (NameError, ModuleNotFoundError, AttributeError) as e:
        print(f"\n❌ %run magic не е наличен: {e}")
        raise ValueError("Няма налични данни! Изпълнете DataProcessing.ipynb първо.")
# Out:
# 📂 Зареждане на данни от файл: /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/data/processed_data.pkl
# ✅ Данните са заредени от файл!

# %%
# Проверка на заредените данни
print("📊 Проверка на данните...\n")

try:
    # Проверяваме дали данните са в паметта
    X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test
    
    print("✅ Данните са успешно заредени!\n")
    
    # Размери на данните
    print(f"📊 Данни за обучение:")
    print(f"   X_train_scaled: {X_train_scaled.shape}")
    print(f"   y_train: {y_train.shape}")
    print(f"\n📊 Данни за валидация:")
    print(f"   X_val_scaled: {X_val_scaled.shape}")
    print(f"   y_val: {y_val.shape}")
    print(f"\n📊 Данни за тестване:")
    print(f"   X_test_scaled: {X_test_scaled.shape}")
    print(f"   y_test: {y_test.shape}")
    
except NameError as e:
    print(f"❌ Данните не са заредени: {e}")
    print("\n💡 Решение:")
    print("   1. Изпълнете DataProcessing.ipynb (секции 0-9) за да създадете processed_data.pkl")
    print("   2. Или използвайте %run magic в клетката по-горе")
    raise
# Out:
# 📊 Проверка на данните...
#
# ✅ Данните са успешно заредени!
#
# 📊 Данни за обучение:
#    X_train_scaled: (755405, 36)
#    y_train: (755405,)
#
# 📊 Данни за валидация:
#    X_val_scaled: (161590, 36)
#    y_val: (161590,)
#
# 📊 Данни за тестване:
#    X_test_scaled: (162155, 36)
#    y_test: (162155,)

# %%
# Подготовка на данните за обучение

# Брой на features
n_features = X_train_scaled.shape[1]
print(f"✅ Брой features: {n_features}")

# Конвертиране към numpy arrays (ако са pandas DataFrames)
if isinstance(X_train_scaled, pd.DataFrame):
    X_train_scaled = X_train_scaled.values
    X_val_scaled = X_val_scaled.values
    X_test_scaled = X_test_scaled.values

if isinstance(y_train, pd.Series):
    y_train = y_train.values
    y_val = y_val.values
    y_test = y_test.values

# Конвертиране към float32 за по-добра производителност
X_train_scaled = X_train_scaled.astype("float32")
X_val_scaled = X_val_scaled.astype("float32")
X_test_scaled = X_test_scaled.astype("float32")
y_train = y_train.astype("float32")
y_val = y_val.astype("float32")
y_test = y_test.astype("float32")

print(f"\n✅ Данните са готови за обучение (float32)")
print(f"   Train: {len(X_train_scaled):,} редове")
print(f"   Val:   {len(X_val_scaled):,} редове")
print(f"   Test:  {len(X_test_scaled):,} редове")
# Out:
# ✅ Брой features: 36
#
# ✅ Данните са готови за обучение (float32)
#    Train: 755,405 редове
#    Val:   161,590 редове
#    Test:  162,155 редове

# %% [markdown]
# ## **2. Model Architecture**
#
# ### **➤ 1. Input Layer**
# - Размерът = броя на входните признаци (features)
# - В нашия случай: **input_dim=22** (22 features)
#
# ### **➤ 2. Hidden Layers**
# Архитектура: **128 → 64 → 32** (класическа пирамида)
# - Dense(128, ReLU) + BatchNorm + Dropout(0.3)
# - Dense(64, ReLU) + BatchNorm + Dropout(0.2)
# - Dense(32, ReLU) + BatchNorm + Dropout(0.1)
#
# ### **➤ 3. Output Layer**
# - 1 неврон (прогноза за продажби)
# - Активация: **linear** (regression задача)
#
# ---

# %%
model = keras.Sequential(
    [
        # Input layer 
        layers.Dense(128, activation="relu", input_shape=(n_features,), name="dense_1"),
        layers.BatchNormalization(name="bn_1"),
        layers.Dropout(0.3, name="dropout_1"),
        
        # Hidden layer 2
        layers.Dense(64, activation="relu", name="dense_2"),
        layers.BatchNormalization(name="bn_2"),
        layers.Dropout(0.2, name="dropout_2"),
        
        # Hidden layer 3
        layers.Dense(32, activation="relu", name="dense_3"),
        layers.BatchNormalization(name="bn_3"),
        layers.Dropout(0.1, name="dropout_3"),
        
        # Output layer
        layers.Dense(1, activation="linear", name="output"),
    ],
    name="MLP_Demand_Forecasting"
)

# Показване на архитектурата
print("📊 Model Architecture:")
model.summary()

# Показване на броя параметри
total_params = model.count_params()

try:
    # За PyTorch backend, използваме numel() за всеки weight
    trainable_params = sum(w.numel() if hasattr(w, 'numel') else int(np.prod(w.shape)) for w in model.trainable_weights)
except:
    # Fallback: в повечето случаи всички параметри са trainable
    trainable_params = total_params

print(f"\n📈 Параметри:")
print(f"   Общо: {total_params:,}")
print(f"   Trainable: {trainable_params:,}")
# Out:
# /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 📊 Model Architecture:
# Model: "MLP_Demand_Forecasting"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 128)            │         4,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_1 (BatchNormalization)       │ (None, 128)            │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_2 (BatchNormalization)       │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_3 (BatchNormalization)       │ (None, 32)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,001 (62.50 KB)
#  Trainable params: 15,553 (60.75 KB)
#  Non-trainable params: 448 (1.75 KB)
# 📈 Параметри:
#    Общо: 16,001
#    Trainable: 15,553

# %% [markdown]
# ## 3. Compile Model
#
# **Optimizer:** Adam (adaptive learning rate)
#
# **Loss:** Mean Squared Error (MSE) - стандартна за regression
#
# **Metrics:** MSE, MAE, RMSE

# %%
def root_mean_squared_error(y_true, y_pred):
    return keras.ops.sqrt(keras.ops.mean(keras.ops.square(y_pred - y_true)))

# Компилиране на модела
model.compile(
    optimizer="adam",
    loss="mse", 
    metrics=[
        "mse", 
        "mae", 
        root_mean_squared_error,  
    ],
)

print("✅ Моделът е компилиран")
print(f"   Optimizer: Adam")
print(f"   Loss: MSE (Mean Squared Error)")
print(f"   Metrics: MSE, MAE, RMSE")
# Out:
# ✅ Моделът е компилиран
#    Optimizer: Adam
#    Loss: MSE (Mean Squared Error)
#    Metrics: MSE, MAE, RMSE

# %% [markdown]
# ## 4. Training
#
# Обучение с:
# - **Early Stopping** - спира при липса на подобрение върху validation set
# - **Model Checkpoint** - запазва най-добрия модел
# - **ReduceLROnPlateau** - намалява learning rate при плато
# - **Validation split** - използваме отделен validation set

# %%
callbacks_list = [
    callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,  
        restore_best_weights=True,  # Връща най-добрите тежести
        verbose=1,
    ),
    
    # Model checkpoint - запазва най-добрия модел
    callbacks.ModelCheckpoint(
        filepath=str(TRAINED_MODELS_DIR / "best_mlp_model.keras"),
        monitor="val_loss",
        save_best_only=True,
        verbose=1,
    ),
    
    # Reduce learning rate при липса на подобрение
    callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,  # Намалява learning rate с 50%
        patience=5,  # Изчаква 5 epochs
        min_lr=1e-7,
        verbose=1,
    ),
]

# Параметри за обучение
BATCH_SIZE = 1024
EPOCHS = 100

print(f"🚀 Започване на обучение...")
print(f"   Batch size: {BATCH_SIZE}")
print(f"   Max epochs: {EPOCHS}")
print(f"   Early stopping: patience=10")
print(f"   Model checkpoint: {MODELS_DIR / 'best_mlp_model.keras'}")

# Обучение на модела
history = model.fit(
    X_train_scaled,
    y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val_scaled, y_val),
    callbacks=callbacks_list,
    verbose=1,
)

print("\n✅ Обучението завърши!")
# Out:
# 🚀 Започване на обучение...
#    Batch size: 1024
#    Max epochs: 100
#    Early stopping: patience=10
#    Model checkpoint: /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# Epoch 1/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5000 - mae: 1.0732 - mse: 7.5000 - root_mean_squared_error: 3.0612
# Epoch 1: val_loss improved from None to 6.33244, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - loss: 6.4299 - mae: 0.9678 - mse: 6.4299 - root_mean_squared_error: 3.1271 - val_loss: 6.3324 - val_mae: 0.9300 - val_mse: 6.3324 - val_root_mean_squared_error: 2.0731 - learning_rate: 0.0010
# Epoch 2/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.5706 - mae: 0.8585 - mse: 5.5706 - root_mean_squared_error: 3.2299
# Epoch 2: val_loss improved from 6.33244 to 5.01268, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.5531 - mae: 0.8422 - mse: 5.5531 - root_mean_squared_error: 3.2215 - val_loss: 5.0127 - val_mae: 0.9030 - val_mse: 5.0127 - val_root_mean_squared_error: 2.0563 - learning_rate: 0.0010
# Epoch 3/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7888 - mae: 0.8278 - mse: 5.7888 - root_mean_squared_error: 3.2478
# Epoch 3: val_loss did not improve from 5.01268
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.4436 - mae: 0.8207 - mse: 5.4436 - root_mean_squared_error: 3.2301 - val_loss: 7.2056 - val_mae: 1.8029 - val_mse: 7.2056 - val_root_mean_squared_error: 2.7173 - learning_rate: 0.0010
# Epoch 4/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3141 - mae: 0.8104 - mse: 5.3141 - root_mean_squared_error: 3.2448
# Epoch 4: val_loss improved from 5.01268 to 4.88393, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.3809 - mae: 0.8061 - mse: 5.3809 - root_mean_squared_error: 3.2437 - val_loss: 4.8839 - val_mae: 0.9350 - val_mse: 4.8839 - val_root_mean_squared_error: 2.0944 - learning_rate: 0.0010
# Epoch 5/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.5133 - mae: 0.8041 - mse: 5.5133 - root_mean_squared_error: 3.2509
# Epoch 5: val_loss did not improve from 4.88393
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.3805 - mae: 0.8023 - mse: 5.3805 - root_mean_squared_error: 3.2381 - val_loss: 5.1037 - val_mae: 0.8389 - val_mse: 5.1037 - val_root_mean_squared_error: 2.0957 - learning_rate: 0.0010
# Epoch 6/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.5956 - mae: 0.8106 - mse: 5.5956 - root_mean_squared_error: 3.2779
# Epoch 6: val_loss did not improve from 4.88393
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.3548 - mae: 0.8015 - mse: 5.3548 - root_mean_squared_error: 3.2436 - val_loss: 5.3660 - val_mae: 1.1972 - val_mse: 5.3660 - val_root_mean_squared_error: 2.1481 - learning_rate: 0.0010
# Epoch 7/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.5971 - mae: 0.8021 - mse: 5.5971 - root_mean_squared_error: 3.2928
# Epoch 7: val_loss improved from 4.88393 to 4.83911, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.3562 - mae: 0.7967 - mse: 5.3562 - root_mean_squared_error: 3.2399 - val_loss: 4.8391 - val_mae: 0.8495 - val_mse: 4.8391 - val_root_mean_squared_error: 2.0904 - learning_rate: 0.0010
# Epoch 8/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1669 - mae: 0.7922 - mse: 5.1669 - root_mean_squared_error: 3.2173
# Epoch 8: val_loss did not improve from 4.83911
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.3354 - mae: 0.7931 - mse: 5.3354 - root_mean_squared_error: 3.2458 - val_loss: 4.8613 - val_mae: 0.8688 - val_mse: 4.8613 - val_root_mean_squared_error: 2.0569 - learning_rate: 0.0010
# Epoch 9/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2711 - mae: 0.7921 - mse: 5.2711 - root_mean_squared_error: 3.2316
# Epoch 9: val_loss did not improve from 4.83911
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - loss: 5.3354 - mae: 0.7932 - mse: 5.3354 - root_mean_squared_error: 3.2450 - val_loss: 4.8678 - val_mae: 0.8990 - val_mse: 4.8678 - val_root_mean_squared_error: 2.0566 - learning_rate: 0.0010
# Epoch 10/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1903 - mae: 0.7899 - mse: 5.1903 - root_mean_squared_error: 3.2224
# Epoch 10: val_loss did not improve from 4.83911
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - loss: 5.3470 - mae: 0.7909 - mse: 5.3470 - root_mean_squared_error: 3.2436 - val_loss: 4.9711 - val_mae: 0.8408 - val_mse: 4.9711 - val_root_mean_squared_error: 2.0618 - learning_rate: 0.0010
# Epoch 11/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3784 - mae: 0.7908 - mse: 5.3784 - root_mean_squared_error: 3.2980
# Epoch 11: val_loss did not improve from 4.83911
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.3145 - mae: 0.7856 - mse: 5.3145 - root_mean_squared_error: 3.2511 - val_loss: 4.9923 - val_mae: 0.9529 - val_mse: 4.9923 - val_root_mean_squared_error: 2.0250 - learning_rate: 0.0010
# Epoch 12/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2578 - mae: 0.7857 - mse: 5.2578 - root_mean_squared_error: 3.2388
# Epoch 12: val_loss did not improve from 4.83911
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.3196 - mae: 0.7847 - mse: 5.3196 - root_mean_squared_error: 3.2452 - val_loss: 4.9121 - val_mae: 1.0064 - val_mse: 4.9121 - val_root_mean_squared_error: 2.1678 - learning_rate: 0.0010
# Epoch 13/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0913 - mae: 0.7760 - mse: 5.0913 - root_mean_squared_error: 3.2165
# Epoch 13: val_loss improved from 4.83911 to 4.83138, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - loss: 5.2846 - mae: 0.7774 - mse: 5.2846 - root_mean_squared_error: 3.2530 - val_loss: 4.8314 - val_mae: 0.8773 - val_mse: 4.8314 - val_root_mean_squared_error: 2.0568 - learning_rate: 5.0000e-04
# Epoch 14/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3247 - mae: 0.7766 - mse: 5.3247 - root_mean_squared_error: 3.2933
# Epoch 14: val_loss did not improve from 4.83138
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.2758 - mae: 0.7754 - mse: 5.2758 - root_mean_squared_error: 3.2580 - val_loss: 4.9304 - val_mae: 0.9536 - val_mse: 4.9304 - val_root_mean_squared_error: 2.0593 - learning_rate: 5.0000e-04
# Epoch 15/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1764 - mae: 0.7775 - mse: 5.1764 - root_mean_squared_error: 3.2369
# Epoch 15: val_loss improved from 4.83138 to 4.82682, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - loss: 5.2771 - mae: 0.7757 - mse: 5.2771 - root_mean_squared_error: 3.2578 - val_loss: 4.8268 - val_mae: 0.8739 - val_mse: 4.8268 - val_root_mean_squared_error: 2.0529 - learning_rate: 5.0000e-04
# Epoch 16/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3021 - mae: 0.7703 - mse: 5.3021 - root_mean_squared_error: 3.2635
# Epoch 16: val_loss improved from 4.82682 to 4.82454, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.2808 - mae: 0.7724 - mse: 5.2808 - root_mean_squared_error: 3.2541 - val_loss: 4.8245 - val_mae: 0.8766 - val_mse: 4.8245 - val_root_mean_squared_error: 2.0632 - learning_rate: 5.0000e-04
# Epoch 17/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.4568 - mae: 0.7769 - mse: 5.4568 - root_mean_squared_error: 3.3071
# Epoch 17: val_loss did not improve from 4.82454
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - loss: 5.2633 - mae: 0.7726 - mse: 5.2633 - root_mean_squared_error: 3.2590 - val_loss: 4.9202 - val_mae: 0.8413 - val_mse: 4.9202 - val_root_mean_squared_error: 2.0640 - learning_rate: 5.0000e-04
# Epoch 18/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1896 - mae: 0.7724 - mse: 5.1896 - root_mean_squared_error: 3.2351
# Epoch 18: val_loss did not improve from 4.82454
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - loss: 5.2582 - mae: 0.7719 - mse: 5.2582 - root_mean_squared_error: 3.2559 - val_loss: 4.9220 - val_mae: 0.8583 - val_mse: 4.9220 - val_root_mean_squared_error: 2.0496 - learning_rate: 5.0000e-04
# Epoch 19/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.4986 - mae: 0.7731 - mse: 5.4986 - root_mean_squared_error: 3.2896
# Epoch 19: val_loss did not improve from 4.82454
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.2429 - mae: 0.7691 - mse: 5.2429 - root_mean_squared_error: 3.2590 - val_loss: 4.8727 - val_mae: 0.9271 - val_mse: 4.8727 - val_root_mean_squared_error: 2.0713 - learning_rate: 5.0000e-04
# Epoch 20/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.2758 - mae: 0.7661 - mse: 5.2758 - root_mean_squared_error: 3.2661
# Epoch 20: val_loss did not improve from 4.82454
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 5.2431 - mae: 0.7696 - mse: 5.2431 - root_mean_squared_error: 3.2603 - val_loss: 4.8881 - val_mae: 0.8581 - val_mse: 4.8881 - val_root_mean_squared_error: 2.0537 - learning_rate: 5.0000e-04
# Epoch 21/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0981 - mae: 0.7661 - mse: 5.0981 - root_mean_squared_error: 3.2306
# Epoch 21: val_loss did not improve from 4.82454
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 5.2495 - mae: 0.7685 - mse: 5.2495 - root_mean_squared_error: 3.2620 - val_loss: 4.9154 - val_mae: 0.9933 - val_mse: 4.9154 - val_root_mean_squared_error: 2.0867 - learning_rate: 5.0000e-04
# Epoch 22/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3922 - mae: 0.7635 - mse: 5.3922 - root_mean_squared_error: 3.2779
# Epoch 22: val_loss did not improve from 4.82454
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2299 - mae: 0.7645 - mse: 5.2299 - root_mean_squared_error: 3.2644 - val_loss: 4.8808 - val_mae: 0.8381 - val_mse: 4.8808 - val_root_mean_squared_error: 2.0547 - learning_rate: 2.5000e-04
# Epoch 23/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3586 - mae: 0.7666 - mse: 5.3586 - root_mean_squared_error: 3.2824
# Epoch 23: val_loss improved from 4.82454 to 4.79016, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2185 - mae: 0.7634 - mse: 5.2185 - root_mean_squared_error: 3.2645 - val_loss: 4.7902 - val_mae: 0.9214 - val_mse: 4.7902 - val_root_mean_squared_error: 2.0957 - learning_rate: 2.5000e-04
# Epoch 24/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1976 - mae: 0.7591 - mse: 5.1976 - root_mean_squared_error: 3.2490
# Epoch 24: val_loss did not improve from 4.79016
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - loss: 5.2212 - mae: 0.7606 - mse: 5.2212 - root_mean_squared_error: 3.2586 - val_loss: 4.8133 - val_mae: 0.8565 - val_mse: 4.8133 - val_root_mean_squared_error: 2.0613 - learning_rate: 2.5000e-04
# Epoch 25/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1360 - mae: 0.7621 - mse: 5.1360 - root_mean_squared_error: 3.2561
# Epoch 25: val_loss did not improve from 4.79016
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - loss: 5.2250 - mae: 0.7615 - mse: 5.2250 - root_mean_squared_error: 3.2645 - val_loss: 4.8512 - val_mae: 0.8258 - val_mse: 4.8512 - val_root_mean_squared_error: 2.0686 - learning_rate: 2.5000e-04
# Epoch 26/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0702 - mae: 0.7574 - mse: 5.0702 - root_mean_squared_error: 3.2341
# Epoch 26: val_loss did not improve from 4.79016
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.2181 - mae: 0.7624 - mse: 5.2181 - root_mean_squared_error: 3.2633 - val_loss: 4.9697 - val_mae: 0.8160 - val_mse: 4.9697 - val_root_mean_squared_error: 2.0612 - learning_rate: 2.5000e-04
# Epoch 27/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1827 - mae: 0.7586 - mse: 5.1827 - root_mean_squared_error: 3.2519
# Epoch 27: val_loss improved from 4.79016 to 4.77448, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2174 - mae: 0.7606 - mse: 5.2174 - root_mean_squared_error: 3.2599 - val_loss: 4.7745 - val_mae: 0.8679 - val_mse: 4.7745 - val_root_mean_squared_error: 2.0714 - learning_rate: 2.5000e-04
# Epoch 28/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1559 - mae: 0.7614 - mse: 5.1559 - root_mean_squared_error: 3.2559
# Epoch 28: val_loss did not improve from 4.77448
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - loss: 5.2178 - mae: 0.7622 - mse: 5.2178 - root_mean_squared_error: 3.2671 - val_loss: 4.8898 - val_mae: 0.8417 - val_mse: 4.8898 - val_root_mean_squared_error: 2.0614 - learning_rate: 2.5000e-04
# Epoch 29/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1635 - mae: 0.7561 - mse: 5.1635 - root_mean_squared_error: 3.2521
# Epoch 29: val_loss did not improve from 4.77448
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.2134 - mae: 0.7593 - mse: 5.2134 - root_mean_squared_error: 3.2594 - val_loss: 4.8206 - val_mae: 0.9486 - val_mse: 4.8206 - val_root_mean_squared_error: 2.0847 - learning_rate: 2.5000e-04
# Epoch 30/100
# 736/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.4128 - mae: 0.7628 - mse: 5.4128 - root_mean_squared_error: 3.2975
# Epoch 30: val_loss did not improve from 4.77448
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2214 - mae: 0.7595 - mse: 5.2214 - root_mean_squared_error: 3.2638 - val_loss: 4.8631 - val_mae: 0.8447 - val_mse: 4.8631 - val_root_mean_squared_error: 2.0595 - learning_rate: 2.5000e-04
# Epoch 31/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1524 - mae: 0.7573 - mse: 5.1524 - root_mean_squared_error: 3.2448
# Epoch 31: val_loss improved from 4.77448 to 4.74880, saving model to /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/best_mlp_model.keras
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - loss: 5.2111 - mae: 0.7595 - mse: 5.2111 - root_mean_squared_error: 3.2659 - val_loss: 4.7488 - val_mae: 0.8639 - val_mse: 4.7488 - val_root_mean_squared_error: 2.0920 - learning_rate: 2.5000e-04
# Epoch 32/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.4131 - mae: 0.7604 - mse: 5.4131 - root_mean_squared_error: 3.2812
# Epoch 32: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.2121 - mae: 0.7599 - mse: 5.2121 - root_mean_squared_error: 3.2647 - val_loss: 4.8263 - val_mae: 0.9313 - val_mse: 4.8263 - val_root_mean_squared_error: 2.0730 - learning_rate: 2.5000e-04
# Epoch 33/100
# 736/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1360 - mae: 0.7571 - mse: 5.1360 - root_mean_squared_error: 3.2522
# Epoch 33: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.2003 - mae: 0.7577 - mse: 5.2003 - root_mean_squared_error: 3.2674 - val_loss: 4.7909 - val_mae: 0.8870 - val_mse: 4.7909 - val_root_mean_squared_error: 2.0930 - learning_rate: 2.5000e-04
# Epoch 34/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2914 - mae: 0.7621 - mse: 5.2914 - root_mean_squared_error: 3.3003
# Epoch 34: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2018 - mae: 0.7581 - mse: 5.2018 - root_mean_squared_error: 3.2681 - val_loss: 4.8361 - val_mae: 0.8268 - val_mse: 4.8361 - val_root_mean_squared_error: 2.0720 - learning_rate: 2.5000e-04
# Epoch 35/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2181 - mae: 0.7647 - mse: 5.2181 - root_mean_squared_error: 3.2870
# Epoch 35: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2014 - mae: 0.7575 - mse: 5.2014 - root_mean_squared_error: 3.2642 - val_loss: 4.8171 - val_mae: 0.9008 - val_mse: 4.8171 - val_root_mean_squared_error: 2.0678 - learning_rate: 2.5000e-04
# Epoch 36/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3083 - mae: 0.7558 - mse: 5.3083 - root_mean_squared_error: 3.2604
# Epoch 36: val_loss did not improve from 4.74880
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2182 - mae: 0.7584 - mse: 5.2182 - root_mean_squared_error: 3.2602 - val_loss: 4.8750 - val_mae: 0.9084 - val_mse: 4.8750 - val_root_mean_squared_error: 2.0464 - learning_rate: 2.5000e-04
# Epoch 37/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3030 - mae: 0.7600 - mse: 5.3030 - root_mean_squared_error: 3.2975
# Epoch 37: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 5.1918 - mae: 0.7563 - mse: 5.1918 - root_mean_squared_error: 3.2724 - val_loss: 4.8195 - val_mae: 0.8824 - val_mse: 4.8195 - val_root_mean_squared_error: 2.0566 - learning_rate: 1.2500e-04
# Epoch 38/100
# 737/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1371 - mae: 0.7526 - mse: 5.1371 - root_mean_squared_error: 3.2524
# Epoch 38: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.1878 - mae: 0.7546 - mse: 5.1878 - root_mean_squared_error: 3.2650 - val_loss: 4.7840 - val_mae: 0.8665 - val_mse: 4.7840 - val_root_mean_squared_error: 2.0747 - learning_rate: 1.2500e-04
# Epoch 39/100
# 736/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2053 - mae: 0.7573 - mse: 5.2053 - root_mean_squared_error: 3.2889
# Epoch 39: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.1953 - mae: 0.7551 - mse: 5.1953 - root_mean_squared_error: 3.2681 - val_loss: 4.8352 - val_mae: 0.8685 - val_mse: 4.8352 - val_root_mean_squared_error: 2.0538 - learning_rate: 1.2500e-04
# Epoch 40/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1533 - mae: 0.7529 - mse: 5.1533 - root_mean_squared_error: 3.2304
# Epoch 40: val_loss did not improve from 4.74880
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.1954 - mae: 0.7549 - mse: 5.1954 - root_mean_squared_error: 3.2591 - val_loss: 4.8062 - val_mae: 0.8788 - val_mse: 4.8062 - val_root_mean_squared_error: 2.0628 - learning_rate: 1.2500e-04
# Epoch 41/100
# 736/738 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2639 - mae: 0.7584 - mse: 5.2639 - root_mean_squared_error: 3.2748
# Epoch 41: val_loss did not improve from 4.74880
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 5.2028 - mae: 0.7564 - mse: 5.2028 - root_mean_squared_error: 3.2696 - val_loss: 4.8226 - val_mae: 0.8763 - val_mse: 4.8226 - val_root_mean_squared_error: 2.0592 - learning_rate: 1.2500e-04
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.
#
# ✅ Обучението завърши!

# %% [markdown]
# ## 5. Evaluation
#
# Оценка на модела върху test set с подходящи метрики за regression.

# %%
# Прогнози върху test set
print("📊 Оценка върху test set...")
y_pred = model.predict(X_test_scaled, batch_size=BATCH_SIZE, verbose=1)
y_pred = y_pred.flatten()  # Преобразуване към 1D array

# Изчисляване на метрики
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

# Допълнителни метрики
mape = np.mean(np.abs((y_test - y_pred) / (y_test + 1e-8))) * 100  # Mean Absolute Percentage Error

print(f"\n📈 Метрики върху test set:")
print(f"   MSE:  {mse:.4f}")
print(f"   MAE:  {mae:.4f}")
print(f"   RMSE: {rmse:.4f}")
print(f"   MAPE: {mape:.2f}%")

# Сравнение на train и validation loss от history
if history:
    final_train_loss = history.history["loss"][-1]
    final_val_loss = history.history["val_loss"][-1]
    
    print(f"\n📊 Final loss:")
    print(f"   Train: {final_train_loss:.4f}")
    print(f"   Val:   {final_val_loss:.4f}")
    print(f"   Test:  {mse:.4f}")
    
    # Проверка за overfitting
    if final_val_loss > final_train_loss * 1.2:
        print(f"\n⚠️  Възможно overfitting (val_loss > train_loss * 1.2)")
    else:
        print(f"\n✅ Няма признаци за overfitting")
# Out:
# 📊 Оценка върху test set...
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# 📈 Метрики върху test set:
#    MSE:  5.0499
#    MAE:  0.9015
#    RMSE: 2.2472
#    MAPE: 3222863104.00%
#
# 📊 Final loss:
#    Train: 5.2028
#    Val:   4.8226
#    Test:  5.0499
#
# ✅ Няма признаци за overfitting

# %% [markdown]
# ### 5.1. Training History Visualization
#
# Визуализация на learning curves за анализ на обучението.

# %%
import matplotlib.pyplot as plt

if history:
    # Създаване на фигура с две подграфи
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss curves
    axes[0].plot(history.history["loss"], label="Train Loss", linewidth=2)
    axes[0].plot(history.history["val_loss"], label="Validation Loss", linewidth=2)
    axes[0].set_title("Model Loss", fontsize=14, fontweight="bold")
    axes[0].set_xlabel("Epoch", fontsize=12)
    axes[0].set_ylabel("Loss (MSE)", fontsize=12)
    axes[0].legend(fontsize=11)
    axes[0].grid(True, alpha=0.3)
    
    # MAE curves
    if "mae" in history.history:
        axes[1].plot(history.history["mae"], label="Train MAE", linewidth=2)
        axes[1].plot(history.history["val_mae"], label="Validation MAE", linewidth=2)
        axes[1].set_title("Model MAE", fontsize=14, fontweight="bold")
        axes[1].set_xlabel("Epoch", fontsize=12)
        axes[1].set_ylabel("MAE", fontsize=12)
        axes[1].legend(fontsize=11)
        axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Запазване на фигурата
    fig.savefig(TRAINING_DIR / "training_history.png", dpi=300, bbox_inches="tight")
    print(f"✅ Training history визуализация запазена: {MODELS_DIR / 'training_history.png'}")
# Out:
# ✅ Training history визуализация запазена: /Users/filipapopova/source/repos/2526-12b-feedforwardneuralnetwork-hierarchical-demand-forecasting/models/training_history.png
